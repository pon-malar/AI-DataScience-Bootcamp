# %% [markdown]
# # Day 3 – NumPy Operations & Broadcasting
#
# ## Objective
# Learn mathematical operations on NumPy arrays.
#
# **Name:** Ponmalar
#
# **Day:** 3

# %%
import numpy as np

a = np.array([10,20,30,40])
b = np.array([1,2,3,4])

print("Array A:", a)
print("Array B:", b)
# Out:
# Array A: [10 20 30 40]
# Array B: [1 2 3 4]

# %%
print(a+b)
# Out:
# [11 22 33 44]

# %%
print(a-b)
# Out:
# [ 9 18 27 36]

# %%
print(a*b)
# Out:
# [ 10  40  90 160]

# %%
print(a/b)
# Out:
# [10. 10. 10. 10.]

# %%
print(a**2)
# Out:
# [ 100  400  900 1600]

# %%
print(np.sqrt(a))
# Out:
# [3.16227766 4.47213595 5.47722558 6.32455532]

# %%
a * b
# Out:
# array([ 10,  40,  90, 160])

# %%
a.dot(b)
# Out:
# np.int64(300)

# %%
import numpy as np

marks = np.array([80, 90, 70, 60])

print("Original Marks:")
print(marks)

print("\nAfter adding 5 grace marks:")
print(marks + 5)
# Out:
# Original Marks:
# [80 90 70 60]
#
# After adding 5 grace marks:
# [85 95 75 65]

# %%
print(marks * 2)
# Out:
# [160 180 140 120]

# %%
a = np.array([10,20,30])

b = np.array([1])

print(a + b)
# Out:
# [11 21 31]

# %%
prices = np.array([100,200,300,400])

gst = 18

final_price = prices + gst

print(final_price)
# Out:
# [118 218 318 418]
