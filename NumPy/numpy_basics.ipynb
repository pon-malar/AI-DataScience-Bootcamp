# %% [markdown]
# # NumPy Basics
#
# ## Day 1
#
# ### Objective
# Learn the fundamentals of NumPy and understand how to create arrays.
#
# **Name:** Ponmalar
#
# **Date:** 13-07-2026

# %%
import numpy as np
numbers=np.array([10,20,30,40,50])
print(numbers)
print(type(numbers))
print(numbers.shape)
print(numbers.dim)
print(numbers.size)
print(numbers.dtype)
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>
# (5,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 6
#       2 numbers=np.array([10,20,30,40,50])
#       3 print(numbers)
#       4 print(type(numbers))
#       5 print(numbers.shape)
# ----> 6 print(numbers.dim)
#       7 print(numbers.size)
#       8 print(numbers.dtype)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dim'

# %%
import numpy as np

print("Hello Ponmalar!")
print("NumPy Version:", np.__version__)
# Out:
# Hello Ponmalar!
# NumPy Version: 2.4.6

# %%
import numpy as np

print("Hello Ponmalar!")
print("Welcome to AI & Data Science 🚀")
print("NumPy Version:", np.__version__)
# Out:
# Hello Ponmalar!
# Welcome to AI & Data Science 🚀
# NumPy Version: 2.4.6

# %%
import numpy as np

numbers = np.array([10, 20, 30, 40, 50])

print(numbers)
print(type(numbers))
print(numbers.shape)
print(numbers.ndim)
print(numbers.size)
print(numbers.dtype)
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>
# (5,)
# 1
# 5
# int64

# %%
import numpy as np

marks = np.array([85, 90, 78, 92, 88])

print("Marks:", marks)
print("Highest:", marks.max())
print("Lowest:", marks.min())
print("Average:", marks.mean())
print("Sum:", marks.sum())
# Out:
# Marks: [85 90 78 92 88]
# Highest: 92
# Lowest: 78
# Average: 86.6
# Sum: 433
